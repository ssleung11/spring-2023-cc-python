# %% [markdown]
# # Simple Data Processing using Pandas

# %% [markdown]
# ## Data source
#
# This notebook uses a sample of the the [The Stanford Open Policing Project](https://openpolicing.stanford.edu/)'s Oakland dataset. A description of the data is [here](https://openpolicing.stanford.edu/data).
#
# <br>
#
# ## Data format
#
# The data is a [CSV file](https://en.wikipedia.org/wiki/Comma-separated_values). CSV stands for *comma-separated values*. It is a very common format for large data files. Here's a view of our data, simplified for right now:
#
# <div style="width: 60%; margin: auto;">
#
# ```
# date,time,location
# 2013-04-01,20:52:00,700 Blk Of Center St
# 2013-04-01,15:55:00,73R D AV&INTERNATIONAL BLVD
# NA,01:33:00,E. 28th St. & Park BLVD
# ```
#
# </div>
#
# CSVs hold *tabular* data (i.e. rows and columns of information). Each line of the file indicates a rows. Each comma indicates a new column.
#
# |date | time | location |
# |:----|:-----|:---------|
# |2013-04-01|20:52:00|700 Blk Of Center St|
# |2013-04-01|15:55:00|73R D AV&INTERNATIONAL BLVD|
# |NA|01:33:00|E. 28th St. & Park BLVD|
#
# <br>
#
# ## Python tools
#
# Python is a great tool for processing CSV data at a large scale or with a lot of complexity. There are several ways to go about this task: with [Python's built-in `csv` module](https://docs.python.org/3/library/csv.html), with the [`Numpy` library](https://numpy.org/), or with the [`Pandas` library](https://pandas.pydata.org/). Read more about the differences [here].
#
# All are worth knowing. This notebook uses `Pandas`.
#
# [here]: https://janakiev.com/blog/csv-in-python/
#
# <hr>

# %% [markdown]
# ## 1. Creating a `dataframe` object

# %%
# Import Pandas (Python Data Analysis Library)
# You'll first have to install it if you haven't already.
# (https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html)
import pandas as pd
# Out:
# /Users/shirley/anaconda3/lib/python3.7/site-packages/setuptools/_importlib.py:23: UserWarning: `importlib-metadata` version is incompatible with `setuptools`.
# This problem is likely to be solved by installing an updated version of `importlib-metadata`.
#   warnings.warn(msg)  # Ensure a descriptive message is shown.
# /Users/shirley/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
# The name of the csv file (in the same folder as this notebook)
path = 'ca_oakland_2020_04_01_SHORT.csv'

# %%
# Here, we create a 'dataframe' object using our csv data.
# Dataframe objects are specific to the Pandas library.
# 'df' is common shorthand for 'dataframe'.
df = pd.read_csv(path)

# %%
# One nice thing about the dataframe object is it lets us
# view our csv data as an easy-to-read table.
df
# Out:
#    raw_row_number        date      time                     location  \
# 0           17213         NaN  01:33:00      E. 28th St. & Park BLVD
# 1           17214         NaN  14:48:00             1759 SEMINARY AV
# 2               1  2013-04-01  00:00:00       31st St And Mlk Jr Way
# 3               2  2013-04-01  00:01:00  3000 Block Of San Pablo Ave
# 4              19  2013-04-01  10:41:00             12th St/Broadway
# ..            ...         ...       ...                          ...
# 93             46  2013-04-02  08:55:00            8400 EDGEWATER DR
# 94             47  2013-04-02  09:20:00       3100 Blk Of FILBERT ST
# 95            123  2013-04-03  10:02:00        90T H &BANCROFT AV AV
# 96            124  2013-04-03  10:13:00    82ND AVE & MACARTHUR BLVD
# 97            125  2013-04-03  10:15:00            8200blk MacArthur
#
#           lat         lng beat subject_age            subject_race  \
# 0   37.803084 -122.237247  NaN         NaN  asian/pacific islander
# 1   37.767568 -122.196820  NaN         NaN                   black
# 2   37.820599 -122.270734  NaN         NaN                   white
# 3   37.821246 -122.276488  NaN         NaN                   black
# 4   37.802937 -122.271738  NaN         NaN                hispanic
# ..        ...         ...  ...         ...                     ...
# 93  37.739000 -122.198904  NaN         NaN                   black
# 94  37.821939 -122.277994  NaN         NaN                hispanic
# 95  37.746171 -122.160355  NaN         NaN                hispanic
# 96  37.762685 -122.164894  NaN         NaN                   black
# 97  37.762876 -122.164814  NaN         NaN                   black
#
#    subject_sex  ... contraband_weapons search_conducted  search_basis  \
# 0       female  ...                NaN            FALSE           NaN
# 1         male  ...              False             TRUE         other
# 2         male  ...              False             TRUE         other
# 3         male  ...                NaN            FALSE           NaN
# 4       female  ...                NaN            FALSE           NaN
# ..         ...  ...                ...              ...           ...
# 93        male  ...                NaN            FALSE           NaN
# 94        male  ...              False             TRUE         other
# 95      female  ...                NaN            FALSE           NaN
# 96      female  ...                NaN            FALSE           NaN
# 97      female  ...                NaN            FALSE           NaN
#
#       reason_for_stop use_of_force_description raw_subject_sdrace  \
# 0   Traffic Violation                      NaN                  A
# 1    Probation/Parole                      NaN                  B
# 2   Traffic Violation                      NaN                  W
# 3   Traffic Violation                      NaN                  B
# 4      Probable Cause                      NaN                  H
# ..                ...                      ...                ...
# 93     Probable Cause                      NaN                  B
# 94     Probable Cause                      NaN                  H
# 95  Traffic Violation                      NaN                  H
# 96  Traffic Violation                      NaN                  B
# 97  Traffic Violation                      NaN                  B
#
#    raw_subject_resultofencounter raw_subject_searchconducted  \
# 0                      Citation,                          No
# 1                     FI Report,                         Yes
# 2                       Warning,                         Yes
# 3                     FI Report,                          No
# 4                      Citation,                          No
# ..                           ...                         ...
# 93                     Citation,                          No
# 94                Felony Arrest,                         Yes
# 95                    FI Report,                          No
# 96                     Citation,                          No
# 97                     Citation,                          No
#
#    raw_subject_typeofsearch raw_subject_resultofsearch
# 0                       NaN                        NaN
# 1             Prob./Parole,                        NaN
# 2             Prob./Parole,                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ..                      ...                        ...
# 93                      NaN                        NaN
# 94      Incident to Arrest,                        NaN
# 95                      NaN                        NaN
# 96                      NaN                        NaN
# 97                      NaN                        NaN
#
# [98 rows x 28 columns]

# %% [markdown]
# ## Navigating the `dataframe` object

# %%
# Show only the first five lines of the dataframe object.
df.head(5)
# Out:
#   raw_row_number        date      time                     location  \
# 0          17213         NaN  01:33:00      E. 28th St. & Park BLVD
# 1          17214         NaN  14:48:00             1759 SEMINARY AV
# 2              1  2013-04-01  00:00:00       31st St And Mlk Jr Way
# 3              2  2013-04-01  00:01:00  3000 Block Of San Pablo Ave
# 4             19  2013-04-01  10:41:00             12th St/Broadway
#
#          lat         lng beat subject_age            subject_race subject_sex  \
# 0  37.803084 -122.237247  NaN         NaN  asian/pacific islander      female
# 1  37.767568 -122.196820  NaN         NaN                   black        male
# 2  37.820599 -122.270734  NaN         NaN                   white        male
# 3  37.821246 -122.276488  NaN         NaN                   black        male
# 4  37.802937 -122.271738  NaN         NaN                hispanic      female
#
#    ... contraband_weapons search_conducted  search_basis    reason_for_stop  \
# 0  ...                NaN            FALSE           NaN  Traffic Violation
# 1  ...              False             TRUE         other   Probation/Parole
# 2  ...              False             TRUE         other  Traffic Violation
# 3  ...                NaN            FALSE           NaN  Traffic Violation
# 4  ...                NaN            FALSE           NaN     Probable Cause
#
#   use_of_force_description raw_subject_sdrace raw_subject_resultofencounter  \
# 0                      NaN                  A                     Citation,
# 1                      NaN                  B                    FI Report,
# 2                      NaN                  W                      Warning,
# 3                      NaN                  B                    FI Report,
# 4                      NaN                  H                     Citation,
#
#   raw_subject_searchconducted raw_subject_typeofsearch  \
# 0                          No                      NaN
# 1                         Yes            Prob./Parole,
# 2                         Yes            Prob./Parole,
# 3                          No                      NaN
# 4                          No                      NaN
#
#   raw_subject_resultofsearch
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 28 columns]

# %%
# Grab only specific columns.
df[['lat','lng']]
# Out:
#           lat         lng
# 0   37.803084 -122.237247
# 1   37.767568 -122.196820
# 2   37.820599 -122.270734
# 3   37.821246 -122.276488
# 4   37.802937 -122.271738
# ..        ...         ...
# 93  37.739000 -122.198904
# 94  37.821939 -122.277994
# 95  37.746171 -122.160355
# 96  37.762685 -122.164894
# 97  37.762876 -122.164814
#
# [98 rows x 2 columns]

# %%
# Grab all of the data where the 'reason_for_stop' column is 'Probable Cause'.
df[df['reason_for_stop'] == 'Probable Cause']
# Out:
#    raw_row_number        date      time                          location  \
# 4              19  2013-04-01  10:41:00                  12th St/Broadway
# 9              23  2013-04-01  16:37:00          200 Blk W.MACARTHUR BLVD
# 12             26  2013-04-01  18:59:00  30TH ST&MARTIN LUTHER KING JR WY
# 14             28  2013-04-01  20:52:00              700 Blk Of Center St
# 30             10  2013-04-01  06:24:00           1844 INTERNATIONAL BLVD
# 38             18  2013-04-01  09:52:00                  12th St/Alice St
# 41          50|51  2013-04-02  10:35:00                     4000 BROADWAY
# 45             55  2013-04-02  11:12:00                   IFO 414 13th St
# 47             57  2013-04-02  11:32:00                    471 DOUGLAS AV
# 48          58|59  2013-04-02  11:39:00                9700 Blk Empire Rd
# 53             64  2013-04-02  13:33:00                 1500 Jefferson St
# 54             65  2013-04-02  13:43:00         2300 Blk Of SAN PABLO AVE
# 56             67  2013-04-02  14:06:00               1000 Blk Of 24th St
# 60             71  2013-04-02  15:16:00             100th Ave & Walnut St
# 62             73  2013-04-02  15:33:00            92nd Ave And Walnut St
# 65             77  2013-04-02  16:14:00                566 Hegenberger Rd
# 66             78  2013-04-02  17:18:00           5040 International Blvd
# 67             79  2013-04-02  17:25:00                AUSEON AV&OLIVE ST
# 73             85  2013-04-02  20:31:00           5040 International Blvd
# 74             86  2013-04-02  20:32:00                      7520 Ney Ave
# 76             88  2013-04-02  20:42:00                   IFO 690 30TH ST
# 82             38  2013-04-02  00:22:00       46T H AV&INTERNATIONAL BLVD
# 86             96  2013-04-02  23:45:00                      1218 97TH AV
# 93             46  2013-04-02  08:55:00                 8400 EDGEWATER DR
# 94             47  2013-04-02  09:20:00            3100 Blk Of FILBERT ST
#
#           lat         lng beat subject_age subject_race subject_sex  ...  \
# 4   37.802937 -122.271738  NaN         NaN     hispanic      female  ...
# 9   37.822949 -122.255766  NaN         NaN        black      female  ...
# 12  37.819659 -122.270973  NaN         NaN        black        male  ...
# 14  37.805385 -122.294913  NaN         NaN        white        male  ...
# 30  37.786781 -122.241171  NaN         NaN     hispanic        male  ...
# 38  37.801072 -122.267293  NaN         NaN        black        male  ...
# 41  37.827611 -122.256283  NaN         NaN        black        male  ...
# 45  37.803503 -122.270738  NaN         NaN        black        male  ...
# 47  37.731723 -122.182077  NaN         NaN        black        male  ...
# 48  37.731753 -122.193366  NaN         NaN        black        male  ...
# 53  37.806434 -122.274345  NaN         NaN     hispanic        male  ...
# 54  37.813879 -122.274278  NaN         NaN        black        male  ...
# 56  37.816457 -122.280226  NaN         NaN        black        male  ...
# 60  37.743387 -122.166924  NaN         NaN        black        male  ...
# 62  37.749732 -122.171556  NaN         NaN     hispanic        male  ...
# 65  37.745022 -122.195668  NaN         NaN        black        male  ...
# 66  37.769497 -122.207969  NaN         NaN     hispanic        male  ...
# 67  37.755437 -122.169548  NaN         NaN     hispanic        male  ...
# 73  37.769497 -122.207969  NaN         NaN        black        male  ...
# 74  37.769074 -122.169172  NaN         NaN        black        male  ...
# 76  37.819935 -122.272009  NaN         NaN        black        male  ...
# 82  37.770824 -122.211756  NaN         NaN        black        male  ...
# 86  37.743596 -122.173714  NaN         NaN        black        male  ...
# 93  37.739000 -122.198904  NaN         NaN        black        male  ...
# 94  37.821939 -122.277994  NaN         NaN     hispanic        male  ...
#
#    contraband_weapons search_conducted    search_basis reason_for_stop  \
# 4                 NaN            FALSE             NaN  Probable Cause
# 9               False             TRUE  probable cause  Probable Cause
# 12                NaN            FALSE             NaN  Probable Cause
# 14              False             TRUE           other  Probable Cause
# 30              False             TRUE  probable cause  Probable Cause
# 38                NaN            FALSE             NaN  Probable Cause
# 41                NaN            FALSE             NaN  Probable Cause
# 45                NaN            FALSE             NaN  Probable Cause
# 47                NaN            FALSE             NaN  Probable Cause
# 48              False             TRUE           other  Probable Cause
# 53                NaN            FALSE             NaN  Probable Cause
# 54                NaN            FALSE             NaN  Probable Cause
# 56                NaN            FALSE             NaN  Probable Cause
# 60              False             TRUE  probable cause  Probable Cause
# 62              False             TRUE  probable cause  Probable Cause
# 65                NaN            FALSE             NaN  Probable Cause
# 66              False             TRUE           other  Probable Cause
# 67              False             TRUE  probable cause  Probable Cause
# 73              False             TRUE           other  Probable Cause
# 74              False             TRUE  probable cause  Probable Cause
# 76              False             TRUE           other  Probable Cause
# 82                NaN            FALSE             NaN  Probable Cause
# 86              False             TRUE           other  Probable Cause
# 93                NaN            FALSE             NaN  Probable Cause
# 94              False             TRUE           other  Probable Cause
#
#    use_of_force_description raw_subject_sdrace raw_subject_resultofencounter  \
# 4                       NaN                  H                     Citation,
# 9                       NaN                  B                    FI Report,
# 12                      NaN                  B                    FI Report,
# 14                      NaN                  W                    FI Report,
# 30                      NaN                  H                    FI Report,
# 38                      NaN                  B                     Citation,
# 41                      NaN                  B                     Citation,
# 45                      NaN                  B                     Citation,
# 47                      NaN                  B                    FI Report,
# 48                      NaN                  B     FI Report,|Felony Arrest,
# 53                      NaN                  H                    FI Report,
# 54                      NaN                  B                     Citation,
# 56                      NaN                  B                     Citation,
# 60                      NaN                  B           Misdemeanor Arrest,
# 62                      NaN                  H                    FI Report,
# 65                      NaN                  B                     Citation,
# 66                      NaN                  H                     Citation,
# 67                      NaN                  H                    FI Report,
# 73                      NaN                  B                    FI Report,
# 74                      NaN                  B                    FI Report,
# 76                      NaN                  B                Felony Arrest,
# 82                      NaN                  B                    FI Report,
# 86                      NaN                  B                Felony Arrest,
# 93                      NaN                  B                     Citation,
# 94                      NaN                  H                Felony Arrest,
#
#    raw_subject_searchconducted raw_subject_typeofsearch  \
# 4                           No                      NaN
# 9                          Yes                 Weapons,
# 12                          No                      NaN
# 14                         Yes            Prob./Parole,
# 30                         Yes                 Weapons,
# 38                          No                      NaN
# 41                          No                      NaN
# 45                          No                      NaN
# 47                          No                      NaN
# 48                      No|Yes   NA|Incident to Arrest,
# 53                          No                      NaN
# 54                          No                      NaN
# 56                          No                      NaN
# 60                         Yes                 Weapons,
# 62                         Yes                 Weapons,
# 65                          No                      NaN
# 66                         Yes            Prob./Parole,
# 67                         Yes                 Weapons,
# 73                         Yes            Prob./Parole,
# 74                         Yes                 Weapons,
# 76                         Yes      Incident to Arrest,
# 82                          No                      NaN
# 86                         Yes      Incident to Arrest,
# 93                          No                      NaN
# 94                         Yes      Incident to Arrest,
#
#    raw_subject_resultofsearch
# 4                         NaN
# 9                         NaN
# 12                        NaN
# 14                        NaN
# 30                        NaN
# 38                        NaN
# 41                        NaN
# 45                        NaN
# 47                        NaN
# 48                        NaN
# 53                        NaN
# 54                        NaN
# 56                        NaN
# 60                        NaN
# 62                        NaN
# 65                        NaN
# 66                        NaN
# 67                        NaN
# 73                        NaN
# 74                        NaN
# 76                        NaN
# 82                        NaN
# 86                        NaN
# 93                        NaN
# 94                        NaN
#
# [25 rows x 28 columns]

# %% [markdown]
# ## 3. Creating simple visualizations

# %%
# Dataframe objects come with plotting methods.
# Here, we create a scatter plot using the lng and lat columns
# of data.
df.plot.scatter(x='lng',
                y='lat',
                c='DarkBlue')

# %%
# Get only one column of data.
df_reason = df[['reason_for_stop']]

# Create a pie chart for that column of data.
df_reason.apply(pd.value_counts).plot.pie(y='reason_for_stop',
                                          figsize=(8, 8))

# %% [markdown]
# ## 4. Because today we will learn about dictionaries...

# %%
# If a dataset doesn't already exist, we can also use Python to
# make one, and then convert it into a dataframe.

# Create custom data in dictionary format.
custom_data = {
    'State': ['Maine', 'New Hampshire', 'Rhode Island', 'Connecticut', 'Delaware'],
    'Dataset Available': [False, True, True, True, False],
    'Dataset Size (Num Stops Logged)': [0, 259822, 509671, 1193774,0]
}

# Use the custom data to create a new DataFrame object.
df = pd.DataFrame(custom_data,
                  columns = ['State',
                             'Dataset Available',
                             'Dataset Size (Num Stops Logged)'])

# Display the DataFrame object.
df
# Out:
#            State  Dataset Available  Dataset Size (Num Stops Logged)
# 0          Maine              False                                0
# 1  New Hampshire               True                           259822
# 2   Rhode Island               True                           509671
# 3    Connecticut               True                          1193774
# 4       Delaware              False                                0

# %%
# Plot our custom data using the advanta
df.plot.bar(x='State', y='Dataset Size (Num Stops Logged)', rot=0)
